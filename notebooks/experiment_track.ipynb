# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
center_x, center_y = 1, 1
radius = 1

theta = np.random.uniform(0, 2 * np.pi, 50)

x = center_x + radius * np.cos(theta)
y = center_y + radius * np.sin(theta)

fig, ax = plt.subplots()
ax.scatter(x, y, color='red')
ax.set_aspect('equal')
plt.show()

# %%
# np.savetxt(f'../data/circle.txt', np.vstack([x,y]).T)
min_dist = 2*np.pi

# %%
X_sa = np.loadtxt('../experiment/simulated_annealing_EXP_24.txt')
X_rs = np.loadtxt('../experiment/random_search_EXP_37.txt')

# %%
fig, ax = plt.subplots(figsize=(7,5))
ax.plot(np.full(int(np.max(X_sa[:, 0])), 2*np.pi), label='ground truth')
ax.plot(X_sa[:, 0], X_sa[:, 1], label='simulated annealing')
ax.plot(X_rs[:, 0], X_rs[:, 1], label='random search')

plt.legend()
